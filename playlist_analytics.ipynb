# %%
from pytubefix import YouTube

# %%
yt = YouTube("https://www.youtube.com/watch?v=jXXdxRcmpNY&list=PL4Zw9c69A3DsFBRK5FFEIMhgXHCbyXjJp")

# %%
yt.title
# Out:
# 'Kargin Haghordum sketch 103 (Hayko Mko)'
