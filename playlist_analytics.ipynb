# %%
import time
from tqdm import tqdm  
from pytubefix import Playlist, YouTube

# %%
def get_info(url: str) -> dict:
    """Fetches about a YouTube video.

    Note:
        Returns 1.title, 2.views, 3.date, 4.likes

    args:
        url (str): The URL of YouTube video.

    Returns:
        dict: A dictionary containing the videos title, ...
    """ 
    yt = YouTube(url)

    data = {
        "title" : yt.title,
        "views" : yt.views,
        "data" : yt.publish_date,
        "likes" : yt.likes,
        "length" : yt.length
    }
    return data

# %% [markdown]
# Playlist

# %%
URL = "https://www.youtube.com/watch?v=aloH6wQKMuw&list=PLDDuEZQEC_uALLtKyjvhf0L9uhaibZ6Vn"

all_videos = [] 

pl = Playlist(URL)

# %%
for i in tqdm(pl.videos):
    all_videos.append(get_info(i.watch_url))
# Out:
# 100%|██████████| 9/9 [00:21<00:00,  2.42s/it]

# %%
all_videos
# Out:
# [{'title': 'Kargin Serial 3 episode 1 (Hayko Mko)',
#   'views': 1024822,
#   'data': datetime.datetime(2013, 3, 12, 14, 49, 42, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))),
#   'likes': '5403',
#   'length': 1418},
#  {'title': 'Kargin Serial 3 episode 2 (Hayko Mko)',
#   'views': 751457,
#   'data': datetime.datetime(2013, 3, 12, 14, 54, 42, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))),
#   'likes': '3819',
#   'length': 1552},
#  {'title': 'Kargin Serial 3 episode 3 (Hayko Mko)',
#   'views': 708211,
#   'data': datetime.datetime(2013, 3, 12, 15, 3, 56, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))),
#   'likes': '3748',
#   'length': 1532},
#  {'title': 'Kargin Serial 3 episode 4 (Hayko Mko)',
#   'views': 607701,
#   'data': datetime.datetime(2013, 3, 12, 15, 3, 45, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))),
#   'likes': '3030',
#   'length': 1474},
#  {'title': 'Kargin Serial 3 episode 5 (Hayko Mko)',
#   'views': 1550744,
#   'data': datetime.datetime(2013, 3, 12, 13, 18, 12, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))),
#   'likes': '6367',
#   'length': 1676},
#  {'title': 'Kargin Serial 3 episode 6 (Hayko Mko)',
#   'views': 1272651,
#   'data': datetime.datetime(2013, 3, 12, 13, 18, 58, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))),
#   'likes': '6022',
#   'length': 1427},
#  {'title': 'Kargin Serial 3 episode 7(Hayko Mko)',
#   'views': 889973,
#   'data': datetime.datetime(2013, 3, 12, 13, 14, 31, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))),
#   'likes': '4322',
#   'length': 1558},
#  {'title': 'Kargin Serial 2 episode 8 (Hayko Mko)',
#   'views': 908672,
#   'data': datetime.datetime(2013, 3, 12, 13, 16, 15, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))),
#   'likes': '4303',
#   'length': 1575},
#  {'title': 'Kargin Serial 3 episode 9 (Hayko Mko)',
#   'views': 638554,
#   'data': datetime.datetime(2013, 3, 12, 14, 21, 37, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))),
#   'likes': '2333',
#   'length': 1362}]
